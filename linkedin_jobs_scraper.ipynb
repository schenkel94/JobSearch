# %% [markdown]
# # 🕵️ LinkedIn Job Hunter (Notebook - Versão Final Otimizada)
# Este notebook utiliza geoIds específicos para garantir que a localidade seja respeitada, ordena os resultados por data e interrompe a busca automaticamente ao chegar no fim dos resultados.

# %%
# Instalação das dependências
# !pip install requests beautifulsoup4 pandas

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import re

# --- 1. CONFIGURAÇÕES DE CARGO E PÁGINAS ---
QUERY_ROLE = "Analista de Dados"
MAX_PAGES = 15
SLEEP_SECONDS = 3.0

# --- 2. LOCALIDADE (Escolha o geoId na lista abaixo) ---
# Exemplos: Brasil (País): 106057199 | São Paulo (Estado): 104815124 | América Latina: 91000007
GEO_ID = "106057199" # Padrão: Brasil (País)

# --- 3. MODALIDADE (WORKPLACE TYPE) ---
WORKPLACE_TYPE = "2"  # -> REMOTO
# WORKPLACE_TYPE = "3"  # -> HÍBRIDO
# WORKPLACE_TYPE = "1"  # -> PRESENCIAL

# --- 4. DATA DE PUBLICAÇÃO ---
TIME_POSTED = "r86400"   # -> ÚLTIMAS 24H
# TIME_POSTED = "r43200"   # -> ÚLTIMAS 12H
# TIME_POSTED = "r3600"    # -> ÚLTIMA HORA

# --- 5. FILTRO DE RELEVÂNCIA (WHITELIST) ---
TITLE_WHITELIST = [
    "Analista de Dados",
    "Data Analyst",
    "Business Intelligence",
    "BI"
]

# %%
headers = {'User-Agent': 'Mozilla/5.0'}

def title_matches(title_txt, terms):
    if not title_txt or not terms: return False
    regex = re.compile('(' + '|'.join([re.escape(t) for t in terms]) + ')', flags=re.IGNORECASE)
    return regex.search(str(title_txt).strip()) is not None

def parse_job_cards(html_txt, terms):
    soup = BeautifulSoup(html_txt, 'html.parser')
    job_lis = soup.select('li')
    
    if not job_lis: return None # Indica fim dos resultados

    rows_list = []
    for li in job_lis:
        title_el = li.select_one('h3.base-search-card__title')
        cargo_val = title_el.get_text(strip=True) if title_el else None
        
        if not title_matches(cargo_val, terms): continue

        time_el = li.select_one('time')
        rows_list.append({
            'Cargo': cargo_val,
            'Empresa': li.select_one('h4.base-search-card__subtitle').get_text(strip=True),
            'Publicada em': time_el.get_text(strip=True) if time_el else "N/A",
            'Data_ISO': time_el.get('datetime') if time_el else "0000-00-00",
            'Link': li.select_one('a.base-card__full-link').get('href').split('?')[0]
        })
    return rows_list

# %%
all_rows = []
seen_links = set()
base_url = 'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search'

print(f"🚀 Iniciando busca: {QUERY_ROLE} | geoId: {GEO_ID}")

for page_idx in range(MAX_PAGES):
    print(f"Lendo página {page_idx + 1}... (Vagas filtradas: {len(all_rows)})")
    
    params = {
        'keywords': QUERY_ROLE, 'geoId': GEO_ID, 'f_WT': WORKPLACE_TYPE, 
        'f_TPR': TIME_POSTED, 'start': page_idx * 25
    }
    
    try:
        resp = requests.get(base_url, params=params, headers=headers, timeout=30)
        if resp.status_code != 200: break
        
        rows = parse_job_cards(resp.text, TITLE_WHITELIST)
        if rows is None: 
            print("ℹ️ Fim dos resultados atingido.")
            break
        
        for r in rows:
            if r['Link'] not in seen_links:
                seen_links.add(r['Link'])
                all_rows.append(r)
        
        time.sleep(SLEEP_SECONDS)
    except: break

print("\n✅ Busca finalizada!")

# %%
if all_rows:
    df = pd.DataFrame(all_rows)
    # ORDENAÇÃO POR RECÊNCIA
    df = df.sort_values(by='Data_ISO', ascending=False).drop(columns=['Data_ISO'])
    print(f"Total de vagas: {len(df)}")
    display(df)
else:
    print("Nenhuma vaga encontrada.")
