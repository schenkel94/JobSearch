# %% [markdown]
# # 🕵️ LinkedIn Job Hunter (Notebook Edition - Otimizado)
# Este notebook agora interrompe a execução automaticamente se o LinkedIn parar de retornar vagas, economizando tempo e processamento.

# %%
# Instalação das dependências necessárias
# !pip install requests beautifulsoup4 pandas

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import re

# --- 1. CONFIGURAÇÕES BÁSICAS ---
QUERY_ROLE = "Analista de Dados"
LOCATION = "Brasil"
MAX_PAGES = 15
SLEEP_SECONDS = 3.0

# --- 2. MODALIDADE (WORKPLACE TYPE) ---
WORKPLACE_TYPE = "2"  # -> REMOTO (Ativo)
# WORKPLACE_TYPE = "3"  # -> HÍBRIDO
# WORKPLACE_TYPE = "1"  # -> PRESENCIAL
# WORKPLACE_TYPE = ""   # -> QUALQUER

# --- 3. DATA DE PUBLICAÇÃO ---
TIME_POSTED = "r86400"   # -> ÚLTIMAS 24H (Ativo)
# TIME_POSTED = "r3600"    # -> ÚLTIMA HORA
# TIME_POSTED = "r43200"   # -> ÚLTIMAS 12H
# TIME_POSTED = "r604800"  # -> ÚLTIMA SEMANA
# TIME_POSTED = "r2592000" # -> ÚLTIMO MÊS
# TIME_POSTED = ""        # -> QUALQUER MOMENTO

# --- 4. FILTRO DE RELEVÂNCIA (WHITELIST) ---
TITLE_WHITELIST = [
    "Analista de Dados",
    "Data Analyst",
    "Business Intelligence",
    "BI"
]

# %%
headers_obj = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
}

def title_matches(title_txt, terms):
    if not title_txt or not terms:
        return False
    regex = re.compile('(' + '|'.join([re.escape(t) for t in terms]) + ')', flags=re.IGNORECASE)
    return regex.search(str(title_txt).strip()) is not None

def parse_job_cards(html_txt, terms):
    soup_obj = BeautifulSoup(html_txt, 'html.parser')
    job_lis = soup_obj.select('li')
    
    # OTIMIZAÇÃO: Se não houver 'li', a página está vazia
    if not job_lis:
        return None

    rows_list = []
    for li_obj in job_lis:
        title_el = li_obj.select_one('h3.base-search-card__title')
        company_el = li_obj.select_one('h4.base-search-card__subtitle')
        time_el = li_obj.select_one('time')
        link_el = li_obj.select_one('a.base-card__full-link')

        cargo_val = title_el.get_text(strip=True) if title_el else None
        if not title_matches(cargo_val, terms):
            continue

        empresa_val = company_el.get_text(strip=True) if company_el else None
        publicada_val = time_el.get_text(strip=True) if time_el else None
        link_val = link_el.get('href').split('?')[0] if link_el else None

        if cargo_val:
            rows_list.append({
                'Cargo': cargo_val,
                'Empresa': empresa_val,
                'Publicada em': publicada_val,
                'Link': link_val
            })
    return rows_list

# %%
all_rows = []
seen_links = set()
page_size = 25 
base_url = 'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search'

print(f"🚀 Iniciando busca: {QUERY_ROLE} | {LOCATION}")

for page_idx in range(MAX_PAGES):
    start_idx = page_idx * page_size
    print(f"Lendo página {page_idx + 1}... (Vagas acumuladas: {len(all_rows)})")
    
    params_obj = {
        'keywords': QUERY_ROLE,
        'location': LOCATION,
        'f_WT': WORKPLACE_TYPE,
        'f_TPR': TIME_POSTED,
        'start': start_idx
      }
    
    try:
        resp = requests.get(base_url, params=params_obj, headers=headers_obj, timeout=30)
        if resp.status_code != 200:
            print(f"⚠️ Status {resp.status_code}. Interrompendo.")
            break
        
        # Chama a função com a lógica de detecção de fim de página
        rows = parse_job_cards(resp.text, TITLE_WHITELIST)
        
        if rows is None:
            print(f"ℹ️ Fim dos resultados atingido na página {page_idx + 1}.")
            break
        
        for r in rows:
            if r['Link'] not in seen_links:
                seen_links.add(r['Link'])
                all_rows.append(r)
        
        time.sleep(SLEEP_SECONDS)
        
    except Exception as e:
        print(f"❌ Erro: {e}")
        break

print("\n✅ Busca finalizada!")

# %%
if all_rows:
    df = pd.DataFrame(all_rows)
    print(f"Total de vagas encontradas: {len(df)}")
    display(df)
else:
    print("Nenhuma vaga encontrada para os critérios selecionados.")
